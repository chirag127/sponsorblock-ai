# %%
from google.colab import drive

drive.mount("/content/gdrive")

# %%
# %pip install -r requirements.txt

# %%
from yt_api import get_videos_from_pl_or_c_id

a = get_videos_from_pl_or_c_id("UCuyRsHZILrU7ZDIAbGASHdA", 300)
print(a)
print(len(a))

# %%
# !python main.py

# %%
# %pip install wrapt_timeout_decorator

# %%
import time
from wrapt_timeout_decorator import *


@timeout(10, use_signals=False)
def mytest():
    print("hello")
    for i in range(1, 10):
        time.sleep(1)
        print(f"{i}")
        try:
            mytest2()
        except Exception as e:
            print(e)


@timeout(5, use_signals=False)
def mytest2():
    print("hello")
    for i in range(1, 10):
        time.sleep(1)
        print(f"{i}")


if __name__ == "__main__":
    mytest()

# %%
# !python tt.py

# %%
from IPython.display import clear_output

# %pip install yt-dlp
# !sudo apt update
# !sudo apt-get install ffmpeg python3 python3-dev curl git -y
# %pip install git+https://github.com/BingLingGroup/autosub.git@dev ffmpeg-normalize langcodes
clear_output()

# %%
# %pip install vulture

# %%
# %pip install coverage

# %%
# !coverage run -m main "study"

# %%
# !vulture yt_api.py

# %%
from preprocess import get_words_by_autosub

# %%
get_words_by_autosub(
    "e5qC1YGRMKI", language_code="hi-IN", duration=540, is_recognized=False
)

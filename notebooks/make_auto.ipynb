# %%
# %pip install isodate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# video_ids is initialized
# Processing playlist id: PL_BnV0cOaQVqvoMfZBIqbuJUqswZAoqE9
# []

# %%
# %python auto_intro.py
